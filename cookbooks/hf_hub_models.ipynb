# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (0.23.0)
# Requirement already satisfied: filelock in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from huggingface_hub) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from huggingface_hub) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from huggingface_hub) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from requests->huggingface_hub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jackiexc/GitHub/LLM_Cookbooks/venv/lib/python3.11/site-packages (from requests->huggingface_hub) (2024.2.2)

# %%
from huggingface_hub import InferenceClient
client = InferenceClient()
models = client.list_deployed_models()

# %%
models
# Out:
# {'conversational': ['facebook/blenderbot-3B',
#   'facebook/blenderbot-400M-distill',
#   'kookyklavicle/SeanDiazBot2',
#   'microsoft/DialoGPT-large',
#   'microsoft/DialoGPT-medium',
#   'microsoft/DialoGPT-small',
#   'model-attribution-challenge/DialoGPT-large',
#   'stabilityai/stable-diffusion-xl-base-1.0'],
#  'text-to-image': ['Bakanayatsu/ponyDiffusion-V6-XL-Turbo-DPO',
#   'cagliostrolab/animagine-xl-3.1',
#   'cloudqi/cqi_text_to_image_pt_v0',
#   'common-canvas/CommonCanvas-XL-C',
#   'dataautogpt3/ProteusV0.3',
#   'digiplay/AbsoluteReality_v1.0_diffusers',
#   'digiplay/AbsoluteReality_v1.8.1',
#   'digiplay/AI-infinity-V1-fp16',
#   'digiplay/AnalogMadness-realistic-model-v4',
#   'digiplay/AnalogMadness-realistic-model-v7',
#   'digiplay/AnyPastel',
#   'digiplay/aurorafantasy_v1',
#   'digiplay/Blazarot_blazaroshi',
#   'digiplay/COCOtiFaMix_v2',
#   'digiplay/darkphoenix3D_v1.1',
#   'digiplay/DarkSushi2.5D_v1',
#   'digiplay/fCAnimeMix_v3',
#   'digiplay/fCAnimeMix_v4',
#   'digiplay/HadrianDelice_DeliceV1.5',
#   'digiplay/insaneRealistic_v1',
#   'digiplay/Juggernaut_final',
#   'digiplay/K-main_NEO',
#   'digiplay/majicMIX_lux_v3',
#   'digiplay/majicMIX_realistic_v5',
#   'digiplay/majicMIX_realistic_v7',
#   'digiplay/majicMIXfantasy_v2',
#   'digiplay/majicMixHorror_v1',
#   'digiplay/Noosphere_v4.2',
#   'digiplay/Perfect_Gap_Blend_v1',
#   'digiplay/PerfectDeliberate-Anime_v2',
#   'digiplay/perfectlevel10',
#   'digiplay/SomethingPhenomenal_vivacityV2',
#   'digiplay/xiaomeige_outlineColor_v10',
#   'dreamlike-art/dreamlike-diffusion-1.0',
#   'Fictiverse/Stable_Diffusion_FluidArt_Model',
#   'fluently/Fluently-XL-v2',
#   'frutiemax/VintageKnockers-Pixart-Sigma-XL-2-512-MS',
#   'gsdf/Counterfeit-V2.5',
#   'hakurei/waifu-diffusion',
#   'ItsJayQz/GTA5_Artwork_Diffusion',
#   'lenssssw/roblox-clothing-ai-maker',
#   'liamhvn/nuke-colormax-anime',
#   'nitrosocke/Future-Diffusion',
#   'nitrosocke/Ghibli-Diffusion',
#   'nitrosocke/mo-di-diffusion',
#   'Onodofthenorth/SD_PixelArt_SpriteSheet_Generator',
#   'PixArt-alpha/PixArt-Sigma-XL-2-1024-MS',
#   'playgroundai/playground-v2-1024px-aesthetic',
#   'prompthero/openjourney-v4',
#   'RunDiffusion/Juggernaut-X-v10',
#   'sd-community/sdxl-flash',
#   'segmind/Segmind-Vega',
#   'segmind/SSD-1B',
#   'ShibaDeveloper/olivia-v1.0',
#   'somq/fantassified_icons_v2',
#   'stablediffusionapi/anything-v5',
#   'stablediffusionapi/duchaiten-real3d-nsfw-xl',
#   'stablediffusionapi/explicit-freedom-nsfw-wai',
#   'stablediffusionapi/newrealityxl-global-nsfw',
#   'stablediffusionapi/omnigenxl-nsfw-sfw',
#   'stablediffusionapi/opendalle',
#   'stablediffusionapi/pyros-nsfw-sdxl',
#   'stablediffusionapi/realistic-stock-photo',
#   'TheLastBen/hrrzg-style-768px',
#   'TheMistoAI/MistoLine',
#   'UnfilteredAI/NSFW-GEN-ANIME',
#   'UnfilteredAI/NSFW-GEN-ANIME-v2',
#   'Vargol/PixArt-Sigma_16bit',
#   'Yntec/AbyssOrangeMix',
#   'Yntec/aMovieX',
#   'Yntec/AnythingV3.1',
#   'Yntec/BabeBae',
#   'Yntec/ChickFlick',
#   'Yntec/Crybaby',
#   'Yntec/DegreesOfFreedom',
#   'Yntec/endlessReality',
#   'Yntec/epiCPhotoGasm',
#   'Yntec/Fanta',
#   'Yntec/HyperRealism',
#   'Yntec/iffyMix',
#   'Yntec/IncredibleWorld2',
#   'Yntec/insaneRealistic_v2',
#   'Yntec/KrazyGlue',
#   'Yntec/Luxury',
#   'Yntec/Memento',
#   'Yntec/nuipenimix',
#   'Yntec/nuipenimix2',
#   'Yntec/photoMovieRealistic',
#   'Yntec/realistic-vision-v12',
#   'Yntec/Remedy',
#   'Yntec/RetroLife',
#   'Yntec/SQUEE',
#   'Yntec/TimelessDiffusion768',
#   'Yntec/UltraHighDefinition',
#   'Yntec/YiffyMix'],
#  'automatic-speech-recognition': ['facebook/wav2vec2-large-xlsr-53-spanish',
#   'ivrit-ai/whisper-large-v2-tuned',
#   'openai/whisper-base',
#   'openai/whisper-large-v3',
#   'openai/whisper-medium'],
#  'document-question-answering': ['impira/layoutlm-document-qa'],
#  'feature-extraction': ['aari1995/German_Semantic_STS_V2',
#   'BAAI/bge-base-en-v1.5',
#   'BAAI/bge-m3',
#   'dccuchile/bert-base-spanish-wwm-uncased',
#   'Enoch2090/MAGI',
#   'facebook/bart-base',
#   'guidecare/all-mpnet-base-v2-feature-extraction',
#   'julien-c/distilbert-feature-extraction',
#   'microsoft/codebert-base',
#   'mixedbread-ai/mxbai-embed-large-v1',
#   'questgen/all-mpnet-base-v2-feature-extraction-pipeline',
#   'sebastian-hofstaetter/distilbert-dot-tas_b-b256-msmarco',
#   'sentence-transformers/all-MiniLM-L6-v2',
#   'sentence-transformers/all-mpnet-base-v2',
#   'sentence-transformers/msmarco-bert-base-dot-v5',
#   'sentence-transformers/msmarco-distilbert-base-tas-b',
#   'thenlper/gte-large'],
#  'fill-mask': ['bert-base-uncased',
#   'bert-large-cased-whole-word-masking',
#   'huggingface/CodeBERTa-small-v1',
#   'roberta-large'],
#  'question-answering': ['atharvamundada99/bert-large-question-answering-finetuned-legal',
#   'deepset/bert-large-uncased-whole-word-masking-squad2',
#   'deepset/gelectra-large-germanquad',
#   'deepset/roberta-base-squad2',
#   'deepset/xlm-roberta-base-squad2',
#   'keras-io/transformers-qa',
#   'mcsabai/huBert-fine-tuned-hungarian-squadv1',
#   'mrm8488/longformer-base-4096-finetuned-squadv2',
#   'NeuML/bert-small-cord19qa',
#   'pierrerappolt/cart'],
#  'text-to-audio': ['facebook/musicgen-stereo-medium',
#   'facebook/musicgen-stereo-small'],
#  'text-to-speech': ['Gatozu35/tortoise-tts',
#   'Mofa-Xingche/bert-vits2-2.2-models-jp-6-speaker-tts',
#   'myshell-ai/MeloTTS-English',
#   'or4cl3ai/SoundSlayerAI',
#   'pyp1/VoiceCraft',
#   'suno/bark'],
#  'text-generation': ['01-ai/Yi-1.5-34B-Chat',
#   'abbas/gpt2-horror-stories',
#   'abhinand/gemma-2b-it-tamil-v0.1-alpha',
#   'achrekarom/text_generation',
#   'acrastt/Marx-3B',
#   'AGundawar/chess-410m',
#   'ahxt/LiteLlama-460M-1T',
#   'ai-forever/mGPT-1.3B-mongol',
#   'ai-forever/rugpt3small_based_on_gpt2',
#   'ai21labs/Jamba-tiny-random',
#   'aisquared/dlite-v2-1_5b',
#   'alenusch/rugpt3-paraphraser',
#   'Alethea/GPT2-chitchat',
#   'AlexWortega/instruct_rugptSmall',
#   'Alireza1044/dwight_bert_lm',
#   'amandyk/QazGPT2',
#   'amichalski2/tinyllama-email-model-full',
#   'ankit011/phi-2-code',
#   'appvoid/palmer-002',
#   'asi/gpt-fr-cased-base',
#   'ATGdev/DialoGPT-small-harrypotter',
#   'ayameRushia/gpt2-small-indonesia-fine-tuning-poem',
#   'b3ck1/gpt-neo-125M-finetuned-beer-recipes',
#   'BagleMeetCoffee/s11Km-12',
#   'Barishni-blinchik/uwbruh-124M',
#   'bayartsogt/mongolian-gpt2',
#   'beomi/gemma-ko-2b',
#   'bigcode/octocoder',
#   'bigcode/santacoder',
#   'bigcode/starcoder',
#   'bigcode/starcoder2-15b',
#   'bigcode/starcoder2-3b',
#   'bigscience/bloom',
#   'bigscience/bloom-560m',
#   'bilalRahib/TinyLLama-NSFW-Chatbot',
#   'bprateek/product-description-generator',
#   'bs-modeling-metadata/html-metadata-exp1-subexp1-1857108',
#   'cahya/gpt2-medium-indonesian-story',
#   'cerebras/Cerebras-GPT-111M',
#   'cerebras/Cerebras-GPT-256M',
#   'charent/Phi2-Chinese-0.2B',
#   'chelvan/Gpt-Neo_1.3B_Stock_Prediction',
#   'Chun/DialoGPT-large-dailydialog',
#   'chuxin-llm/Chuxin-1.6B-1M',
#   'Cirilaron/DialoGPT-medium-vergil',
#   'ckip-joint/bloom-1b1-zh',
#   'ckiplab/gpt2-base-chinese',
#   'clancystudios/DialoGPT-medium-Morty',
#   'ClassCat/gpt2-base-french',
#   'codellama/CodeLlama-13b-hf',
#   'codellama/CodeLlama-34b-Instruct-hf',
#   'codellama/CodeLlama-7b-hf',
#   'coffeeee/nsfw-story-generator2',
#   'cognitivecomputations/TinyDolphin-2.8-1.1b',
#   'CohereForAI/aya-23-35B',
#   'CohereForAI/aya-23-8B',
#   'CohereForAI/c4ai-command-r-plus',
#   'Crataco/Pythia-160M-Deduped-Adventure',
#   'cyberagent/open-calm-3b',
#   'daspartho/prompt-extend',
#   'databricks/dolly-v2-3b',
#   'dbddv01/gpt2-french-small',
#   'Deathsquad10/TinyLlamaV5-NewTokenizer',
#   'deepbrain/phi2-gsm8k-rephrase-high-confidence-training',
#   'DeepPavlov/bart-base-en-persona-chat',
#   'Den4ikAI/rugpt3_2ch',
#   'dh-unibe/gpt2-larger-walser',
#   'dh-unibe/luther-xl',
#   'diabolic6045/harry_potter_chatbot',
#   'digit82/kogpt2-summarization',
#   'distilbert/distilgpt2',
#   'EleutherAI/gpt-neo-125m',
#   'EleutherAI/polyglot-ko-1.3b',
#   'EleutherAI/pythia-410m',
#   'emre/spanish-dialoGPT',
#   'ethzanalytics/distilgpt2-tiny-conversational',
#   'eunyounglee/got-neo-var-ppo',
#   'Falah/stable_diffusion_prompts',
#   'Felladrin/Llama-68M-Chat-v1',
#   'flax-community/gpt-neo-125M-apps',
#   'flax-community/gpt2-persian-question-answering',
#   'fractalego/fact-checking',
#   'FredZhang7/anime-anything-promptgen-v2',
#   'GeneZC/MiniChat-1.5-3B',
#   'ghunkins/prompt-expansion',
#   'GItaf/roberta-base-finetuned-mbti-0901',
#   'gnad/viqgen-bloomz-1b1-lorasft',
#   'Gnider/model_old_working',
#   'Gnider/small_mix_5900',
#   'google/gemma-1.1-2b-it',
#   'google/gemma-1.1-7b-it',
#   'google/gemma-2b',
#   'google/gemma-7b',
#   'google/gemma-7b-it',
#   'gpt2-large',
#   'Gustavosta/MagicPrompt-Stable-Diffusion',
#   'h2oai/h2o-danube2-1.8b-base',
#   'Hennara/kuwain.T8.v6',
#   'hf-tiny-model-private/tiny-random-XLMRobertaXLForCausalLM',
#   'hooking-dev/sexyGPT-Uncensored',
#   'HooshvareLab/gpt2-fa-poetry',
#   'huggingartists/death-grips',
#   'huggingartists/elton-john',
#   'huggingartists/queen',
#   'huggingartists/travis-scott',
#   'huggingartists/xxxtentacion',
#   'HuggingFaceFW/ablation-model-fineweb-v1',
#   'HuggingFaceH4/starchat-beta',
#   'HuggingFaceH4/starchat2-15b-v0.1',
#   'HuggingFaceH4/zephyr-7b-alpha',
#   'HuggingFaceH4/zephyr-7b-beta',
#   'HuggingFaceH4/zephyr-orpo-141b-A35b-v0.1',
#   'HuggingFaceM4/idefics-9b-instruct',
#   'huggingtweets/amouranth',
#   'huggingtweets/angelinacho-stillconor-touchofray',
#   'huggingtweets/femboympreg',
#   'huggingtweets/itspublu',
#   'huggingtweets/j_j_j_j_j_jones',
#   'huggingtweets/jackieracc_',
#   'huggingtweets/jaguarunlocked',
#   'huggingtweets/minidiscplus',
#   'huggingtweets/minimalaq',
#   'huggingtweets/stockstotrade',
#   'huggingtweets/wnbagirlfriend',
#   'hzgz/ZymCTRL',
#   'IlyaGusev/rugpt_large_turbo_instructed',
#   'imperialwool/ai-dungeon-medium-rus',
#   'ingen51/DialoGPT-medium-GPT4',
#   'inkoziev/rugpt_chitchat',
#   'ismaelfaro/gpt2-poems.en',
#   'ismaelfaro/gpt2-poems.es',
#   'jampekka/4chan_out',
#   'jarod0411/linker_v3',
#   'Joaoffg/ELM',
#   'jppaolim/homerGPT2',
#   'jrtec/jrtec-gpt2-superheroes-name-generator',
#   'jrtec/jrtec-gpt2-text-generation-quotes-jonathan-vargas',
#   'jtatman/gpt2-open-instruct-v1-Anthropic-hh-rlhf',
#   'jungyuko/DAVinCI-42dot_LLM-PLM-1.3B-v1.2',
#   'kashif/stack-llama-2',
#   'Khoa/llma2-vi-medical-news',
#   'KnutJaegersberg/gpt2-chatbot',
#   'kuttersn/gpt2_chatbot',
#   'laggywiggl/GPT2modelFT',
#   'lingyun1/GZDX-1.1B',
#   'Locutusque/gpt2-medium-conversational',
#   'LorenzoDeMattei/GePpeTto',
#   'lvwerra/starcoderbase-gsm8k',
#   'M4-ai/TinyMistral-6x248M-Instruct',
#   'Maykeye/TinyLLama-v0',
#   'mbien/recipenlg',
#   'MBZUAI/LaMini-GPT-1.5B',
#   'MBZUAI/LaMini-GPT-774M',
#   'meta-llama/Llama-2-13b-chat-hf',
#   'meta-llama/Llama-2-13b-hf',
#   'meta-llama/Llama-2-70b-chat-hf',
#   'meta-llama/Llama-2-7b-chat-hf',
#   'meta-llama/Llama-2-7b-hf',
#   'meta-llama/Meta-Llama-3-70B-Instruct',
#   'meta-llama/Meta-Llama-3-8B-Instruct',
#   'microsoft/biogpt',
#   'microsoft/BioGPT-Large',
#   'microsoft/BioGPT-Large-PubMedQA',
#   'microsoft/DialoGPT-large',
#   'microsoft/DialoGPT-medium',
#   'microsoft/phi-1',
#   'microsoft/phi-1_5',
#   'microsoft/Phi-3-mini-128k-instruct',
#   'microsoft/Phi-3-mini-128k-instruct-onnx',
#   'microsoft/Phi-3-mini-4k-instruct',
#   'Mira-LeafTown/GPT-2-Chinese-AnimeThesaurus',
#   'mistralai/Mistral-7B-Instruct-v0.1',
#   'mistralai/Mistral-7B-Instruct-v0.2',
#   'mistralai/Mistral-7B-Instruct-v0.3',
#   'mistralai/Mistral-7B-v0.1',
#   'mistralai/Mixtral-8x7B-Instruct-v0.1',
#   'mlabonne/chesspythia-70m',
#   'mlabonne/Gemmalpaca-2B',
#   'model-attribution-challenge/bloom-350m',
#   'model-attribution-challenge/codegen-350M-multi',
#   'model-attribution-challenge/distilgpt2',
#   'model-attribution-challenge/gpt2',
#   'model-attribution-challenge/gpt2-xl',
#   'model-attribution-challenge/xlnet-base-cased',
#   'mrm8488/gpt2-finetuned-recipes-cooking_v2',
#   'newtonkwan/gpt2-fine-tuned-debiased',
#   'nilq/mistral-1L-tiny',
#   'ninagroot/Llama-450M',
#   'nlp04/gpt_trinity_2_4_3e-5_lp5_nb5',
#   'NlpHUST/gpt2-vietnamese',
#   'Norod78/hebrew-gpt_neo-small',
#   'NotAiLOL/Athena-TinyLlama-v0.1',
#   'NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO',
#   'NumbersStation/nsql-350M',
#   'numfa/numfalm_v2-1b',
#   'openaccess-ai-collective/tiny-mistral',
#   'openai-community/gpt2',
#   'openai-community/gpt2-large',
#   'openai-community/gpt2-medium',
#   'openai-community/gpt2-xl',
#   'openai-gpt',
#   'OpenAssistant/oasst-sft-1-pythia-12b',
#   'OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5',
#   'peruginia/Llama-2-Small',
#   'Pi3141/DialoGPT-medium-elon-2',
#   'pierreguillou/gpt2-small-portuguese',
#   'PlanTL-GOB-ES/gpt2-base-bne',
#   'prithivMLmods/Stark-Prompt-Extender',
#   'proxectonos/Carballo-cerebras-1.3B',
#   'pyro-glitch/NEMO_AI_Compainon_v0.5',
#   'qgyd2021/lip_service_4chan',
#   'rakeshkiriyath/gpt2Medium_text_to_sql',
#   'rhysjones/phi-2-orange-v2',
#   'rinna/japanese-gpt2-medium',
#   'riotu-lab/ArabianGPT-03B',
#   'roneneldan/TinyStories-1M',
#   'roneneldan/TinyStories-3M',
#   's-nlp/gpt2-base-gedi-detoxification',
#   'Salesforce/codegen-350M-mono',
#   'satvikag/chatbot',
#   'seoyoung-3060/codeparrot-ds',
#   'sgarbi/gpt-nq-prompt-generator',
#   'shahp7575/gpt2-horoscopes',
#   'Sharathhebbar24/chat_gpt2',
#   'SiberiaSoft/ruGPT3_medium_chitchat',
#   'Siddu0406/article-generator',
#   'skt/kogpt2-base-v2',
#   'SSI/dirtybot4bot',
#   'stabilityai/stablelm-2-1_6b',
#   'stabilityai/stablelm-3b-4e1t',
#   'subhashtalluri/Telco_Transformer_V1_Chat',
#   'supermy/jinyong-gpt2',
#   'thinhda/chatbot',
#   'tiiuae/falcon-7b',
#   'timdettmers/guanaco-33b-merged',
#   'TinyLlama/TinyLlama-1.1B-Chat-v0.1',
#   'TinyLlama/TinyLlama-1.1B-intermediate-step-480k-1T',
#   'TinyPixel/small-llama2',
#   'togethercomputer/RedPajama-INCITE-Chat-3B-v1',
#   'Triangles/fantastic_philosopher_124_4000',
#   'trig/sokka-chatbot-test',
#   'tsdocode/text-to-sql',
#   'uer/gpt2-chinese-cluecorpussmall',
#   'UnfilteredAI/Mia-001',
#   'upstage/TinySolar-187m-4k',
#   'veddm/paraphrase-multilingual-MiniLM-L12-v2-finetuned-DIT',
#   'vicgalle/gpt2-open-instruct-v1',
#   'w601sxs/b1ade-1b-bf16',
#   'wjn1996/hugnlp-hugchat-gpt2',
#   'Writer/palmyra-small',
#   'xlnet-base-cased',
#   'XsoraS/outputs2',
#   'Xxanderr/ScraperTrainer',
#   'yzhuang/TinyLlama-1.1B-Chat-v0.1_fictional_arc_challenge_Korean_v1'],
#  'image-classification': ['aalonso-developer/vit-base-clothing-leafs-example',
#   'facebook/deit-base-distilled-patch16-224',
#   'glrh11/vit-base-patch16-224',
#   'google/vit-base-patch16-224',
#   'imjeffhi/pokemon_classifier',
#   'laundryheap/drivers-v1-small',
#   'lysandre/tiny-vit-random',
#   'microsoft/resnet-50',
#   'NTQAI/pedestrian_gender_recognition'],
#  'image-segmentation': ['facebook/maskformer-swin-base-coco',
#   'facebook/maskformer-swin-large-coco',
#   'mattmdjaga/segformer_b2_clothes',
#   'nvidia/segformer-b0-finetuned-ade-512-512',
#   'nvidia/segformer-b5-finetuned-ade-640-640'],
#  'image-to-text': ['dumperize/movie-picture-captioning',
#   'JB/rrg_emnlp_impression_128_rl',
#   'microsoft/trocr-base-str',
#   'microsoft/trocr-large-printed',
#   'microsoft/trocr-large-stage1',
#   'nlpconnect/vit-gpt2-image-captioning',
#   'Salesforce/blip-image-captioning-base',
#   'Salesforce/blip-image-captioning-large',
#   'unum-cloud/uform-gen2-dpo',
#   'unum-cloud/uform-gen2-qwen-500m',
#   'ydshieh/vit-gpt2-coco-en'],
#  'object-detection': ['facebook/detr-resnet-50',
#   'microsoft/table-transformer-structure-recognition-v1.1-pub'],
#  'summarization': ['facebook/bart-large-cnn',
#   'google/pegasus-cnn_dailymail',
#   'google/pegasus-large',
#   'google/pegasus-newsroom',
#   'IlyaGusev/mbart_ru_sum_gazeta',
#   'knkarthick/MEETING_SUMMARY',
#   'lighthousefeed/yoda-fits',
#   'linydub/bart-large-samsum',
#   'sshleifer/distilbart-cnn-12-6',
#   'sshleifer/distilbart-cnn-6-6',
#   'tuner007/pegasus_summarizer'],
#  'text2text-generation': ['allenai/macaw-large',
#   'allenai/t5-small-squad2-question-generation',
#   'astremo/friendly_JA',
#   'bigscience/T0',
#   'bigscience/T0pp',
#   'buddhist-nlp/mbart-buddhist-many-to-one-rev5',
#   'deep-learning-analytics/automatic-title-generation',
#   'diwank/bartner',
#   'facebook/blenderbot-3B',
#   'facebook/blenderbot_small-90M',
#   'facebook/mbart-large-50',
#   'facebook/mbart-large-50-many-to-many-mmt',
#   'google/flan-t5-small',
#   'google/flan-t5-xxl',
#   'grammarly/medit-xl',
#   'Kaludi/chatgpt-gpt4-prompts-bart-large-cnn-samsum',
#   'lrakotoson/scitldr-catts-xsum-ao',
#   'MBZUAI/LaMini-Flan-T5-783M',
#   'metamyth/jenny_prod',
#   'microsoft/GODEL-v1_1-large-seq2seq',
#   'mrm8488/t5-base-finetuned-question-generation-ap',
#   'mrm8488/t5-small-finetuned-imdb-sentiment',
#   'pszemraj/grammar-synthesis-large',
#   'RajSang/pegasus-sports-titles',
#   'Sunbird/sunbird-en-mul',
#   'tuner007/pegasus_paraphrase',
#   'valhalla/t5-base-qa-qg-hl'],
#  'token-classification': ['BobbyG97/German-MedBERT-Birads-NER100',
#   'Davlan/bert-base-multilingual-cased-ner-hrl',
#   'dbmdz/bert-base-cased-finetuned-conll03-english',
#   'dbmdz/bert-large-cased-finetuned-conll03-english',
#   'dbmdz/electra-large-discriminator-finetuned-conll03-english',
#   'dslim/bert-base-NER',
#   'dslim/bert-large-NER',
#   'elastic/distilbert-base-uncased-finetuned-conll03-english',
#   'KB/bert-base-swedish-cased-ner',
#   'oliverguhr/fullstop-punctuation-multilang-large',
#   'Sonatafyai/scibert-finetuned_ADEs_SonatafyAI',
#   'vblagoje/bert-english-uncased-finetuned-pos',
#   'xlm-roberta-large-finetuned-conll03-english'],
#  'translation': ['facebook/mbart-large-50-many-to-many-mmt',
#   'Helsinki-NLP/opus-mt-en-he',
#   'Helsinki-NLP/opus-mt-en-ine',
#   'Helsinki-NLP/opus-mt-en-sit',
#   'Helsinki-NLP/opus-mt-nl-en'],
#  'text-classification': ['AdamCodd/distilroberta-nsfw-prompt-stable-diffusion',
#   'arpanghoshal/EmoRoBERTa',
#   'bhadresh-savani/bert-base-go-emotion',
#   'bhadresh-savani/distilbert-base-uncased-emotion',
#   'cardiffnlp/tweet-topic-19-multi',
#   'cardiffnlp/twitter-roberta-base-sentiment',
#   'cardiffnlp/twitter-roberta-base-sentiment-latest',
#   'cardiffnlp/twitter-xlm-roberta-base-sentiment',
#   'cduesing/bert_workforce',
#   'cross-encoder/ms-marco-MiniLM-L-12-v2',
#   'cross-encoder/msmarco-MiniLM-L6-en-de-v1',
#   'd4data/bias-detection-model',
#   'distilbert-base-uncased-finetuned-sst-2-english',
#   'FartLabs/FART_Chemberta_PubChem10M',
#   'Hello-SimpleAI/chatgpt-detector-roberta',
#   'hossamdaoud/bloomz-1b7-academic-detector',
#   'hubtype/distilbert-base-uncased-nonsense',
#   'ICFNext/EYY-categorisation-1.0',
#   'j-hartmann/emotion-english-distilroberta-base',
#   'jaehyeong/koelectra-base-v3-generalized-sentiment-analysis',
#   'joeddav/distilbert-base-uncased-go-emotions-student',
#   'Kevinger/Hub-Report-1705947362',
#   'KoalaAI/Text-Moderation',
#   'm-newhauser/distilbert-political-tweets',
#   'michellejieli/NSFW_text_classifier',
#   'Mike0307/multilingual-e5-language-detection',
#   'monologg/koelectra-base-v3-hate-speech',
#   'nlptown/bert-base-multilingual-uncased-sentiment',
#   'openai-community/roberta-base-openai-detector',
#   'p-christ/QandAClassifier',
#   'papluca/xlm-roberta-base-language-detection',
#   'pfr/conditional-utilitarian-deberta-01',
#   'pfr/conditional-utilitarian-roberta-01',
#   'pfr/utilitarian-deberta-01',
#   'ProsusAI/finbert',
#   'rayschwartz/new-text-classifications',
#   'roberta-base-openai-detector',
#   's-nlp/roberta_toxicity_classifier',
#   'SamLowe/roberta-base-go_emotions',
#   'siebert/sentiment-roberta-large-english',
#   'simoneteglia/xlm-roberta-europarl-language-detection',
#   'tdrenis/finetuned-bot-detector',
#   'textattack/roberta-base-CoLA',
#   'unitary/toxic-bert',
#   'unitary/unbiased-toxic-roberta',
#   'valurank/distilbert-quality',
#   'valurank/distilroberta-bias',
#   'valurank/distilroberta-clickbait',
#   'valurank/distilroberta-hatespeech',
#   'valurank/distilroberta-news-small',
#   'valurank/distilroberta-offensive',
#   'valurank/distilroberta-propaganda-2class',
#   'valurank/distilroberta-proppy',
#   'Vmuaddib/autotrain-gudel-department-classifier-clean-886428460',
#   'ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli'],
#  'visual-question-answering': ['dandelin/vilt-b32-finetuned-vqa'],
#  'zero-shot-classification': ['facebook/bart-large-mnli',
#   'joeddav/xlm-roberta-large-xnli',
#   'Narsil/deberta-large-mnli-zero-cls',
#   'typeform/distilbert-base-uncased-mnli',
#   'valhalla/distilbart-mnli-12-3'],
#  'zero-shot-image-classification': ['openai/clip-vit-base-patch32'],
#  'image-text-to-text': ['HuggingFaceM4/idefics2-8b',
#   'HuggingFaceM4/idefics2-8b-chatty'],
#  'sentence-similarity': ['aari1995/German_Semantic_STS_V2',
#   'BAAI/bge-base-en-v1.5',
#   'BAAI/bge-m3',
#   'Enoch2090/MAGI',
#   'guidecare/all-mpnet-base-v2-feature-extraction',
#   'mixedbread-ai/mxbai-embed-large-v1',
#   'questgen/all-mpnet-base-v2-feature-extraction-pipeline',
#   'sentence-transformers/all-MiniLM-L6-v2',
#   'sentence-transformers/all-mpnet-base-v2',
#   'sentence-transformers/msmarco-bert-base-dot-v5',
#   'sentence-transformers/msmarco-distilbert-base-tas-b',
#   'thenlper/gte-large']}

# %%
from IPython import display
display.JSON(models)
